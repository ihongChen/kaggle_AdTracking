# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../find/feat_impact11.csv')

# %%
df.sort_values('split',ascending=False)
# Out:
#                   f         gain  split
# 7                ip   3554524.04    218
# 4           channel  27570825.02    148
# 2               app  19202174.66     75
# 3                os   1038111.95     62
# 0         nextClick   2467905.17     55
# 8         ip_tcount    444147.58     21
# 12               X0    943479.98     18
# 6              hour    401164.21     17
# 21      ipday_count   1798322.50     13
# 20               X8    198633.10     11
# 5            device    187715.94      9
# 15               X3    188996.14      9
# 10     ip_app_count    788096.44      8
# 11  ip_app_os_count     36537.71      7
# 13               X1     11788.15      4
# 19               X7      7033.32      3
# 17               X5      8899.54      2
# 18               X6     13913.11      2
# 14               X2      1666.52      1
# 16               X4       408.15      1
# 9    ip_tchan_count         0.00      0
# 1   nextClick_shift         0.00      0

# %%
df.index=df.f
df.drop('f',axis=1,inplace=True)

# %%
df['split'].sort_values(ascending=False).plot(kind='bar')

# %%
df.split.sort_values(ascending=False).to_frame().head(20)
# Out:
#                  split
# f
# ip                 218
# channel            148
# app                 75
# os                  62
# nextClick           55
# ip_tcount           21
# X0                  18
# hour                17
# ipday_count         13
# X8                  11
# X3                   9
# device               9
# ip_app_count         8
# ip_app_os_count      7
# X1                   4
# X7                   3
# X5                   2
# X6                   2
# X2                   1
# X4                   1

# %%
df['gain'].sort_values(ascending=False).plot(kind='bar')

# %%
df.gain.sort_values(ascending=False).to_frame().head(20)
# Out:
#                         gain
# f
# channel          27570825.02
# app              19202174.66
# ip                3554524.04
# nextClick         2467905.17
# ipday_count       1798322.50
# os                1038111.95
# X0                 943479.98
# ip_app_count       788096.44
# ip_tcount          444147.58
# hour               401164.21
# X8                 198633.10
# X3                 188996.14
# device             187715.94
# ip_app_os_count     36537.71
# X6                  13913.11
# X1                  11788.15
# X5                   8899.54
# X7                   7033.32
# X2                   1666.52
# X4                    408.15
